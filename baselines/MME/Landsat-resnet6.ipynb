# %%
import torch
import tqdm
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import os
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import torch.nn.functional as F

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# !nvidia-smi
# Out:
# Tue Oct 29 20:48:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070 Ti     Off | 00000000:06:00.0 Off |                  N/A |
# | 53%   43C    P8              20W / 290W |    778MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce RTX 3080        Off | 00000000:07:00.0 Off |                  N/A |
# |  0%   40C    P8              14W / 340W |    994MiB / 10240MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce RTX 2070 ...    Off | 00000000:08:00.0 Off |                  N/A |
# | 22%   42C    P8              10W / 215W |    728MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
class ResNet6(nn.Module):
    def __init__(self, num_classes=10):
        super(ResNet6, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=6, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.fc = nn.Linear(512, num_classes)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = F.max_pool2d(x, 2)
        x = F.avg_pool2d(x, x.size()[2:])
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
# Check that MPS is available
device = torch.device("cpu")

if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("DEVICE = MPS")

if torch.cuda.is_available():
    device = torch.device("cuda:1")
    print("DEVICE = CUDA")
# Out:
# DEVICE = CUDA

# %%
def set_seed(seed):
    # Set seed for Python's built-in random number generator
    torch.manual_seed(seed)
    # Set seed for numpy
    np.random.seed(seed)
    # Set seed for CUDA if available
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        # Set cuDNN's random number generator seed for deterministic behavior
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# Usage example:
set_seed(69)

# %%
# EarlyStopping class to stop training when validation performance plateaus
class EarlyStopping:
    def __init__(self, patience=5, verbose=False, delta=0, path='best_model.pth'):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 5
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path to save the best model. Default: 'best_model.pth'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decreases.'''
        if self.verbose:
            print(f"Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...")
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
import torch
import numpy as np
import wandb
from sklearn.metrics import precision_recall_fscore_support
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split


def create_optimizer(params, model):
    """
    Creates and returns the optimizer based on the parameter configuration.
    Args:
        params (dict): Contains 'optimizer', 'lr', and other hyperparameters.
        model (nn.Module): The model to optimize.
    Returns:
        optimizer (torch.optim.Optimizer): The initialized optimizer.
    """
    if params['optimizer'] == 'Adam':
        return optim.Adam(model.parameters(), lr=params['lr'])
    if params['optimizer'] == 'AdamW':
        return optim.AdamW(model.parameters(), lr=params['lr'])
    elif params['optimizer'] == 'SGD':
        return optim.SGD(model.parameters(), lr=params['lr'], momentum=0.9)
    elif params['optimizer'] == 'RMSprop':
        return optim.RMSprop(model.parameters(), lr=params['lr'], momentum=0.9)
    else:
        raise ValueError(f"Unsupported optimizer: {params['optimizer']}")

# Custom training function with early stopping, model saving, and optimizer selection
def train_and_validate(model, train_loader, val_loader, config, early_stopping):
    best_loss = np.inf
    best_f1 = 0
    best_model_path = early_stopping.path
    
    # Create optimizer based on the config
    optimizer = create_optimizer(config, model)
    
    # Scheduler can be used for learning rate adjustments
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=1, factor=0.9)

    for epoch in range(config['num_epochs']):
        model.train()
        train_loss = 0.0
        
        for batch_idx, (data, targets, _) in enumerate(train_loader):
            data, targets = data.to(config['device']), targets.to(config['device'])

            optimizer.zero_grad()
            outputs = model(data)
            pos_weight = targets * config['positive_weight_factor']
            criterion = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            
        train_loss /= len(train_loader)
        print(f"Epoch {epoch+1}/{config['num_epochs']}, Train Loss: {train_loss}")
        wandb.log({"train/loss": train_loss, "train/lr": optimizer.param_groups[0]['lr']})

        # Validation
        val_loss, val_f1, val_precision, val_recall = validate(model, val_loader, config)
        wandb.log({"val/loss": val_loss, "val/sF1@25": val_f1, "val/sPrecision@25": val_precision, "val/sRecall@25": val_recall})

        # Early stopping checks
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered!")
            break

        scheduler.step(val_loss)
        print("Scheduler:", scheduler.state_dict())
        
# Updated test loop to calculate AUC
def test_model(model, test_loader, config, seed):
    model.eval()
    test_loss = 0.0
    all_predictions = []
    all_targets = []

    # Load the best model saved by early stopping
    model.load_state_dict(torch.load(f"./models/{config['architecture']}-{config['predictor']}-bestF1-seed_{seed}_opt_{config['optimizer']}_lr_{config['lr']}_batch_{config['batch_size']}_weight{config['positive_weight_factor']}.pth"))

    with torch.no_grad():
        for data, targets, _ in test_loader:
            data = data.to(config["device"])
            targets = targets.to(config["device"])

            outputs = model(data)
            pos_weight = targets * config["positive_weight_factor"]
            criterion = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight)
            test_loss += criterion(outputs, targets).item()

            # Collect raw predictions (probabilities after sigmoid) for AUC calculation
            probabilities = torch.sigmoid(outputs).cpu().numpy()
            all_predictions.append(probabilities)
            all_targets.append(targets.cpu().numpy())

    # Average the test loss
    test_loss /= len(test_loader)

    # Concatenate all predictions and targets
    all_predictions = np.concatenate(all_predictions, axis=0)
    all_targets = np.concatenate(all_targets, axis=0)

    # Calculate AUC (average='macro' or 'micro' may vary depending on your needs)
    # try:
        
    zero_cols_targets = np.all(all_targets == 0, axis=0)
    ones_cols_targets = np.all(all_targets == 1, axis=0)
    zero_cols = zero_cols_targets | ones_cols_targets

    filtered_targets = all_targets[:][:, ~zero_cols]

    list_of_lists = np.asarray([arr.tolist() for arr in all_predictions])
    filtered_probas = list_of_lists[:][:, ~zero_cols]

    # Calculate and print AUC (Area Under ROC Curve)
    auc = roc_auc_score(filtered_targets, filtered_probas, average='macro')

    # except ValueError:
    #     auc = None  # AUC calculation requires at least one positive and one negative sample

    # Calculate Precision, Recall, F1 scores using thresholding on predictions
    top_k_indices = np.argsort(-all_predictions, axis=1)[:, :25]  # Top-25 predictions per sample
    thresholded_predictions = np.zeros_like(all_predictions)
    rows = np.arange(len(all_predictions))[:, None]
    thresholded_predictions[rows, top_k_indices] = 1

    precision, recall, f1, _ = precision_recall_fscore_support(all_targets, thresholded_predictions, average='samples')

    # Log the results to W&B
    wandb.log({
        "test/loss": test_loss,
        "test/sF1@25": f1,
        "test/sPrecision@25": precision,
        "test/sRecall@25": recall,
        "test/AUC": auc
    })

    print(f"Test Loss: {test_loss}, Test Precision: {precision}, Test Recall: {recall}, Test F1: {f1}, Test AuC: {auc}")
        
# Validation function
def validate(model, val_loader, config):
    model.eval()
    val_loss = 0.0
    all_predictions, all_targets = [], []

    with torch.no_grad():
        for data, targets, _ in val_loader:
            data, targets = data.to(config['device']), targets.to(config['device'])
            outputs = model(data)
            pos_weight = targets * config['positive_weight_factor']
            criterion = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight)
            val_loss += criterion(outputs, targets).item()
            
            predictions = torch.sigmoid(outputs).cpu().numpy()
            top_k_indices = np.argsort(-predictions, axis=1)[:, :25]
            thresholded_predictions = np.zeros_like(predictions)
            rows = np.arange(len(predictions))[:, None]
            thresholded_predictions[rows, top_k_indices] = 1

            all_predictions.append(thresholded_predictions)
            all_targets.append(targets.cpu().numpy())
    
    val_loss /= len(val_loader)
    all_predictions = np.concatenate(all_predictions, axis=0)
    all_targets = np.concatenate(all_targets, axis=0)
    precision, recall, f1, _ = precision_recall_fscore_support(all_targets, all_predictions, average='samples', zero_division="warn")
    print(f"Validation Loss: {val_loss}, F1: {f1}, P: {precision}, R: {recall}")
    
    return val_loss, f1, precision, recall

# Function to split the data into training and validation sets
def split_train_val(train_metadata, val_size=0.05, seed=42):
    train_subset, val_subset = train_test_split(train_metadata, test_size=val_size, random_state=seed)
    return train_subset, val_subset

def run_experiment(train_metadata, val_metadata, test_metadata, train_transform, test_transform, param_combinations):
    
    for seed in [1, 66, 123, 777, 999]:  # Random seed for different experiment runs
        
        # Iterate over hyperparameter combinations
        for params in param_combinations:
            config = {
                'architecture': 'ResNet6',
                'predictor': 'LandsatCubes',
                'batch_size': params['batch_size'],
                'lr': params['lr'],
                'num_epochs': params['num_epochs'],
                'positive_weight_factor': params['positive_weight_factor'],
                'optimizer': params['optimizer'],  # Add optimizer to the config
                'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
            }

            # Initialize Weights and Biases (W&B) for logging
            initialize_wandb(config, run_name=f"{config['architecture']}-{config['predictor']}-seed_{seed}_opt_{params['optimizer']}_lr_{params['lr']}_batch_{params['batch_size']}_weight{params['positive_weight_factor']}")
            
                        
            # Create the train and validation datasets
            train_dataset = CustomDataset(data_path_PA, train_metadata, subset="train", transform=transform)
            val_dataset = CustomDataset(data_path_PA, val_metadata, subset="val", transform=transform)

            # Create DataLoader instances for train and validation
            train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True, num_workers=8)
            val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False, num_workers=8)

            # Create the test dataset and loader only once (as it's fixed)
            test_dataset = CustomDataset(test_data_path, test_metadata, subset="test", transform=test_transform)
            test_loader = DataLoader(test_dataset, batch_size=config['batch_size'], shuffle=False, num_workers=8)

            # Initialize the model, optimizer, scheduler, and early stopping
            model = ResNet6(NUM_CLASSES).to(config['device'])
            early_stopping = EarlyStopping(patience=5, verbose=True, path=f"./models/{config['architecture']}-{config['predictor']}-bestF1-seed_{seed}_opt_{params['optimizer']}_lr_{params['lr']}_batch_{params['batch_size']}_weight{params['positive_weight_factor']}.pth")

            # Train and validate
            set_seed(seed)
            train_and_validate(model, train_loader, val_loader, config, early_stopping)

            test_model(model, test_loader, config, seed)
                
            print(f"Finished training for seed {seed}.")

# %%
class CustomDataset(Dataset):
    def __init__(self, data_dir, metadata, subset, transform=None):
        self.subset = subset
        self.transform = transform
        self.data_dir = data_dir
        self.metadata = metadata
        self.metadata = self.metadata.dropna(subset="speciesId").reset_index(drop=True)
        self.metadata['speciesId'] = self.metadata['speciesId'].astype(int)
        self.label_dict = self.metadata.groupby('surveyId')['speciesId'].apply(list).to_dict()
        
        self.metadata = self.metadata.drop_duplicates(subset="surveyId").reset_index(drop=True)


    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        
        survey_id = self.metadata.surveyId[idx]
        if self.subset in ["train", "val"]:
            sample = torch.nan_to_num(torch.load(os.path.join(self.data_dir, f"GLC24-PA-train-landsat-time-series_{survey_id}_cube.pt")))
        else:
            sample = torch.nan_to_num(torch.load(os.path.join(self.data_dir, f"GLC24-PA-test-landsat_time_series_{survey_id}_cube.pt")))
        
        species_ids = self.label_dict.get(survey_id, [])  # Get list of species IDs for the survey ID
        label = torch.zeros(NUM_CLASSES)  # Initialize label tensor
        for species_id in species_ids:
            #label_id = self.species_mapping[species_id]  # Get consecutive integer label
            label_id = species_id
            label[label_id] = 1  # Set the corresponding class index to 1 for each species

        # Ensure the sample is in the correct format for the transform
        if isinstance(sample, torch.Tensor):
            sample = sample.permute(1, 2, 0)  # Change tensor shape from (C, H, W) to (H, W, C)
            sample = sample.numpy()  # Convert tensor to numpy array
            #print(sample.shape)

        if self.transform:
            sample = self.transform(sample)

        return sample, label, survey_id

# %%
# Initialize Weights and Biases
def initialize_wandb(config, run_name="experiment", project_name="GeoPlant"):
    wandb.init(project=project_name, name=run_name, config=config)

# %%
import torch.optim as optim
import itertools

NUM_CLASSES = 11255 # Number of unique classes

transform = transforms.Compose([
    transforms.ToTensor()
])

# File paths for training and testing data
data_path_PA = "../../dataset/SateliteTimeSeries-Landsat/cubes/PA-train-landsat_time_series/"
label_path_PA = "../../metadata/GLC24_PA_metadata_train.csv"
dev_metadata = pd.read_csv(label_path_PA)

val_surveys = dev_metadata.drop_duplicates(subset="surveyId").sample(frac=0.05, random_state=1).surveyId.unique()

val_metadata = dev_metadata[dev_metadata.surveyId.isin(val_surveys)].reset_index(drop=True)
train_metadata = dev_metadata[~dev_metadata.surveyId.isin(val_surveys)].reset_index(drop=True)

test_data_path = "../../dataset/SateliteTimeSeries-Landsat/cubes/PA-test-landsat_time_series/"
test_metadata_path = "../../metadata/PA_metadata_test.csv"
test_labels_path = "../../metadata/test_labels.csv"
test_metadata = pd.read_csv(test_metadata_path)
test_labels = pd.read_csv(test_labels_path)
test_labels["speciesId"] = test_labels["predictions"].str.split()
test_metadata = (
    test_metadata.merge(test_labels[["surveyId", "speciesId"]], on="surveyId", how="inner")
    .explode("speciesId")
    .dropna(subset=["speciesId"])
    .reset_index(drop=True)
)
test_metadata["speciesId"] = test_metadata["speciesId"].astype(int)


param_grid = {
    'batch_size': [32],
    'lr': [0.0001],
    'num_epochs': [50],
    'positive_weight_factor': [1],
    'optimizer': ['AdamW']  # List of optimizers to use
}

# Function to generate all combinations of hyperparameters
def create_param_combinations(param_grid):
    keys, values = zip(*param_grid.items())
    return [dict(zip(keys, combination)) for combination in itertools.product(*values)]

# Generate all possible hyperparameter combinations
param_combinations = create_param_combinations(param_grid)

# Run the experimentnum_classes
run_experiment(train_metadata, val_metadata, test_metadata, train_transform=transform, test_transform=transform, param_combinations=param_combinations)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: picekl. Use `wandb login --relogin` to force relogin
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/Projects/NIPS-GLC24/baselines-v2/landsat/wandb/run-20241029_204930-hbvboztv</code>
# Syncing run <strong><a href='https://wandb.ai/picekl/GeoPlant/runs/hbvboztv' target="_blank">ResNet6-LandsatCubes-seed_1_opt_AdamW_lr_0.0001_batch_32_weight1</a></strong> to <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">https://wandb.ai/picekl/GeoPlant</a>
#  View run at <a href='https://wandb.ai/picekl/GeoPlant/runs/hbvboztv' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/hbvboztv</a>
# Epoch 1/50, Train Loss: 0.013129103400220672
# Validation Loss: 0.005543248501739331, F1: 0.27799651453179247, P: 0.2356844234659474, R: 0.40570623250235655
# Validation loss decreased (inf --> 0.005543).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.005543248501739331, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 1, '_last_lr': [0.0001]}
# Epoch 2/50, Train Loss: 0.005182285967792676
# Validation Loss: 0.005059574426351381, F1: 0.3128111116918687, P: 0.26312429759496514, R: 0.4671108650086177
# Validation loss decreased (0.005543 --> 0.005060).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.005059574426351381, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 2, '_last_lr': [0.0001]}
# Epoch 3/50, Train Loss: 0.004810919548860025
# Validation Loss: 0.00481365205653544, F1: 0.32705326643969646, P: 0.2769071701505956, R: 0.4846817862800684
# Validation loss decreased (0.005060 --> 0.004814).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00481365205653544, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 3, '_last_lr': [0.0001]}
# Epoch 4/50, Train Loss: 0.004613973571334449
# Validation Loss: 0.0046221471740864216, F1: 0.3435682349852273, P: 0.29042930995729377, R: 0.511515235970121
# Validation loss decreased (0.004814 --> 0.004622).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0046221471740864216, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 4, '_last_lr': [0.0001]}
# Epoch 5/50, Train Loss: 0.0044824504404540975
# Validation Loss: 0.0046188798866101674, F1: 0.3412786822129618, P: 0.28863115306810516, R: 0.508452888821026
# Validation loss decreased (0.004622 --> 0.004619).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0046188798866101674, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 5, '_last_lr': [0.0001]}
# Epoch 6/50, Train Loss: 0.0043850264890594615
# Validation Loss: 0.004500875128100493, F1: 0.3518028898191166, P: 0.29853899752753427, R: 0.5209273900559256
# Validation loss decreased (0.004619 --> 0.004501).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004500875128100493, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 6, '_last_lr': [0.0001]}
# Epoch 7/50, Train Loss: 0.00430402790942144
# Validation Loss: 0.004435169623632516, F1: 0.36044820451284754, P: 0.3048415374241403, R: 0.5374744505243212
# Validation loss decreased (0.004501 --> 0.004435).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004435169623632516, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 7, '_last_lr': [0.0001]}
# Epoch 8/50, Train Loss: 0.004235183471146855
# Validation Loss: 0.004446804787897106, F1: 0.3589816658756077, P: 0.3042391548662621, R: 0.5326155602613509
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004435169623632516, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 8, '_last_lr': [0.0001]}
# Epoch 9/50, Train Loss: 0.004172851113947271
# Validation Loss: 0.004382492071350238, F1: 0.36521505273897703, P: 0.30902225219150375, R: 0.5438557252793681
# Validation loss decreased (0.004435 --> 0.004382).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004382492071350238, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 9, '_last_lr': [0.0001]}
# Epoch 10/50, Train Loss: 0.004116345264643634
# Validation Loss: 0.004355511890857347, F1: 0.3659589355381833, P: 0.3107394920206788, R: 0.5425105097734012
# Validation loss decreased (0.004382 --> 0.004356).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004355511890857347, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 10, '_last_lr': [0.0001]}
# Epoch 11/50, Train Loss: 0.004061670775788242
# Validation Loss: 0.0043473965072605225, F1: 0.3659803851863308, P: 0.31082040908069225, R: 0.5421160371325499
# Validation loss decreased (0.004356 --> 0.004347).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0043473965072605225, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 11, '_last_lr': [0.0001]}
# Epoch 12/50, Train Loss: 0.004010762087824521
# Validation Loss: 0.0043383790263240895, F1: 0.3678762978790783, P: 0.3120161834120027, R: 0.5463062395840023
# Validation loss decreased (0.004347 --> 0.004338).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0043383790263240895, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 12, '_last_lr': [0.0001]}
# Epoch 13/50, Train Loss: 0.0039651444225686965
# Validation Loss: 0.004373739915899932, F1: 0.36441301609870097, P: 0.30938188356934143, R: 0.5417381176632764
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0043383790263240895, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 13, '_last_lr': [0.0001]}
# Epoch 14/50, Train Loss: 0.003921608088952599
# Validation Loss: 0.004346206847445241, F1: 0.3675463298223799, P: 0.3112699483029895, R: 0.5476593784668988
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0043383790263240895, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 14, '_last_lr': [9e-05]}
# Epoch 15/50, Train Loss: 0.003855893250384187
# Validation Loss: 0.004327935381193779, F1: 0.36841806774185193, P: 0.3119802202742189, R: 0.5497881375735142
# Validation loss decreased (0.004338 --> 0.004328).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004327935381193779, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 15, '_last_lr': [9e-05]}
# Epoch 16/50, Train Loss: 0.00381672574276983
# Validation Loss: 0.004279621958266944, F1: 0.37471124921243193, P: 0.31775230388851433, R: 0.5575568846100917
# Validation loss decreased (0.004328 --> 0.004280).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004279621958266944, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 16, '_last_lr': [9e-05]}
# Epoch 17/50, Train Loss: 0.0037755257226907445
# Validation Loss: 0.004285819748682636, F1: 0.37394238506532823, P: 0.31713193976174425, R: 0.5565762779222737
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004279621958266944, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 17, '_last_lr': [9e-05]}
# Epoch 18/50, Train Loss: 0.0037367024203729983
# Validation Loss: 0.004315468534228525, F1: 0.3724252002773806, P: 0.3155046077770285, R: 0.5555998996887984
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004279621958266944, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 18, '_last_lr': [8.1e-05]}
# Epoch 19/50, Train Loss: 0.0036819967455184828
# Validation Loss: 0.004267042507750115, F1: 0.3770995805115803, P: 0.31971229489772984, R: 0.5610204852551608
# Validation loss decreased (0.004280 --> 0.004267).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004267042507750115, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 19, '_last_lr': [8.1e-05]}
# Epoch 20/50, Train Loss: 0.0036452811346710133
# Validation Loss: 0.00427167451375031, F1: 0.3761095365878661, P: 0.3191818386154192, R: 0.5581529807886845
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004267042507750115, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 20, '_last_lr': [8.1e-05]}
# Epoch 21/50, Train Loss: 0.003611645848651746
# Validation Loss: 0.004254900604220373, F1: 0.3786588386612512, P: 0.3210429309957294, R: 0.5635923261347803
# Validation loss decreased (0.004267 --> 0.004255).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004254900604220373, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 21, '_last_lr': [8.1e-05]}
# Epoch 22/50, Train Loss: 0.003577479092230813
# Validation Loss: 0.0042914550784709194, F1: 0.3751806918646984, P: 0.31859743762643294, R: 0.5577995601586676
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004254900604220373, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 22, '_last_lr': [8.1e-05]}
# Epoch 23/50, Train Loss: 0.0035456325319496228
# Validation Loss: 0.004300009978136846, F1: 0.37776386686330243, P: 0.320008990784446, R: 0.5632047511153486
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004254900604220373, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 23, '_last_lr': [7.290000000000001e-05]}
# Epoch 24/50, Train Loss: 0.0034973141220860033
# Validation Loss: 0.0042521585610562134, F1: 0.38035861239319074, P: 0.32289503259159363, R: 0.5642235349199113
# Validation loss decreased (0.004255 --> 0.004252).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0042521585610562134, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 24, '_last_lr': [7.290000000000001e-05]}
# Epoch 25/50, Train Loss: 0.003464759303236424
# Validation Loss: 0.00427424155308732, F1: 0.3792641442903501, P: 0.3219689817936615, R: 0.562694290021982
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0042521585610562134, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 25, '_last_lr': [7.290000000000001e-05]}
# Epoch 26/50, Train Loss: 0.003436245650784828
# Validation Loss: 0.004279752501419612, F1: 0.37984357475167463, P: 0.32222072375814786, R: 0.5648565143224139
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0042521585610562134, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 26, '_last_lr': [6.561000000000002e-05]}
# Epoch 27/50, Train Loss: 0.00339229582475088
# Validation Loss: 0.004264635720755905, F1: 0.3788756620943916, P: 0.321420543942459, R: 0.5630938259817061
# EarlyStopping counter: 3 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0042521585610562134, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 27, '_last_lr': [6.561000000000002e-05]}
# Epoch 28/50, Train Loss: 0.0033662144788614927
# Validation Loss: 0.004269223954595093, F1: 0.37896450025440914, P: 0.3215284333558103, R: 0.5637539126388815
# EarlyStopping counter: 4 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0042521585610562134, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 28, '_last_lr': [5.904900000000002e-05]}
# Epoch 29/50, Train Loss: 0.0033253158092284457
# Validation Loss: 0.004265536757053009, F1: 0.3798955214150854, P: 0.32277815239379637, R: 0.5635656436028444
# EarlyStopping counter: 5 out of 5
# Early stopping triggered!
# Test Loss: 0.005897996731643641, Test Precision: 0.26599660729431723, Test Recall: 0.4466666489758059, Test F1: 0.3019379293000911, Test AuC: 0.9198613145964011
# Finished training for seed 1.
# Finishing last run (ID:hbvboztv) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.004 MB of 0.026 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.133604…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>▁</td></tr><tr><td>test/loss</td><td>▁</td></tr><tr><td>test/sF1@25</td><td>▁</td></tr><tr><td>test/sPrecision@25</td><td>▁</td></tr><tr><td>test/sRecall@25</td><td>▁</td></tr><tr><td>train/loss</td><td>█▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/lr</td><td>██████████████▆▆▆▆▅▅▅▅▅▃▃▃▂▂▁</td></tr><tr><td>val/loss</td><td>█▅▄▃▃▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/sF1@25</td><td>▁▃▄▅▅▆▇▇▇▇▇▇▇▇▇██▇███████████</td></tr><tr><td>val/sPrecision@25</td><td>▁▃▄▅▅▆▇▇▇▇▇▇▇▇▇██▇███████████</td></tr><tr><td>val/sRecall@25</td><td>▁▄▄▆▆▆▇▇▇▇▇▇▇▇▇██████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>0.91986</td></tr><tr><td>test/loss</td><td>0.0059</td></tr><tr><td>test/sF1@25</td><td>0.30194</td></tr><tr><td>test/sPrecision@25</td><td>0.266</td></tr><tr><td>test/sRecall@25</td><td>0.44667</td></tr><tr><td>train/loss</td><td>0.00333</td></tr><tr><td>train/lr</td><td>6e-05</td></tr><tr><td>val/loss</td><td>0.00427</td></tr><tr><td>val/sF1@25</td><td>0.3799</td></tr><tr><td>val/sPrecision@25</td><td>0.32278</td></tr><tr><td>val/sRecall@25</td><td>0.56357</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ResNet6-LandsatCubes-seed_1_opt_AdamW_lr_0.0001_batch_32_weight1</strong> at: <a href='https://wandb.ai/picekl/GeoPlant/runs/hbvboztv' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/hbvboztv</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241029_204930-hbvboztv/logs</code>
# Successfully finished last run (ID:hbvboztv). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668022216375297, max=1.0…
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/Projects/NIPS-GLC24/baselines-v2/landsat/wandb/run-20241029_211033-e1r6mgs3</code>
# Syncing run <strong><a href='https://wandb.ai/picekl/GeoPlant/runs/e1r6mgs3' target="_blank">ResNet6-LandsatCubes-seed_66_opt_AdamW_lr_0.0001_batch_32_weight1</a></strong> to <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">https://wandb.ai/picekl/GeoPlant</a>
#  View run at <a href='https://wandb.ai/picekl/GeoPlant/runs/e1r6mgs3' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/e1r6mgs3</a>
# Epoch 1/50, Train Loss: 0.013122847909002052
# Validation Loss: 0.005621038487048022, F1: 0.2706529944360555, P: 0.2297774780849629, R: 0.39433550642548926
# Validation loss decreased (inf --> 0.005621).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.005621038487048022, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 1, '_last_lr': [0.0001]}
# Epoch 2/50, Train Loss: 0.005208747444077226
# Validation Loss: 0.004990324802097997, F1: 0.3165540140519445, P: 0.2674938188356934, R: 0.46969338290416257
# Validation loss decreased (0.005621 --> 0.004990).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004990324802097997, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 2, '_last_lr': [0.0001]}
# Epoch 3/50, Train Loss: 0.004833487777852289
# Validation Loss: 0.004817864162448261, F1: 0.3303986447228726, P: 0.2781928523263655, R: 0.4950263606054694
# Validation loss decreased (0.004990 --> 0.004818).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004817864162448261, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 3, '_last_lr': [0.0001]}
# Epoch 4/50, Train Loss: 0.004632404457688202
# Validation Loss: 0.004644037671719811, F1: 0.3429977550800135, P: 0.2900427062261183, R: 0.5104127708160229
# Validation loss decreased (0.004818 --> 0.004644).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004644037671719811, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 4, '_last_lr': [0.0001]}
# Epoch 5/50, Train Loss: 0.004502497010996155
# Validation Loss: 0.00457046510418877, F1: 0.3472483298582708, P: 0.29383681726230615, R: 0.5163960906909904
# Validation loss decreased (0.004644 --> 0.004570).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00457046510418877, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 5, '_last_lr': [0.0001]}
# Epoch 6/50, Train Loss: 0.004400967986479452
# Validation Loss: 0.004524189504861299, F1: 0.3513935738398805, P: 0.29736120476511574, R: 0.5219228884273012
# Validation loss decreased (0.004570 --> 0.004524).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004524189504861299, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 6, '_last_lr': [0.0001]}
# Epoch 7/50, Train Loss: 0.00432264520860729
# Validation Loss: 0.00445979710701587, F1: 0.35829802575311653, P: 0.30280062935491125, R: 0.5348605178564216
# Validation loss decreased (0.004524 --> 0.004460).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00445979710701587, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 7, '_last_lr': [0.0001]}
# Epoch 8/50, Train Loss: 0.004251488765830669
# Validation Loss: 0.004432516570003437, F1: 0.35796849176497286, P: 0.3035558552483704, R: 0.5319637027277127
# Validation loss decreased (0.004460 --> 0.004433).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004432516570003437, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 8, '_last_lr': [0.0001]}
# Epoch 9/50, Train Loss: 0.004187095186526462
# Validation Loss: 0.004431588382327131, F1: 0.35783339008486065, P: 0.30329512249943813, R: 0.5325890553233315
# Validation loss decreased (0.004433 --> 0.004432).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004431588382327131, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 9, '_last_lr': [0.0001]}
# Epoch 10/50, Train Loss: 0.004130923256551583
# Validation Loss: 0.00435576455867184, F1: 0.36716911146614845, P: 0.31119802202742186, R: 0.5461533649670688
# Validation loss decreased (0.004432 --> 0.004356).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00435576455867184, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 10, '_last_lr': [0.0001]}
# Epoch 11/50, Train Loss: 0.004078034134839015
# Validation Loss: 0.004353510556809072, F1: 0.3689834850444879, P: 0.3127084738143403, R: 0.5482379890993729
# Validation loss decreased (0.004356 --> 0.004354).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004353510556809072, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 11, '_last_lr': [0.0001]}
# Epoch 12/50, Train Loss: 0.004026497882279024
# Validation Loss: 0.0043454895644182605, F1: 0.36833361311636786, P: 0.3127444369521241, R: 0.5467349788665752
# Validation loss decreased (0.004354 --> 0.004345).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0043454895644182605, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 12, '_last_lr': [0.0001]}
# Epoch 13/50, Train Loss: 0.003979484220268029
# Validation Loss: 0.004358247266749719, F1: 0.36503049260930215, P: 0.3096785794560576, R: 0.5416916362685386
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0043454895644182605, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 13, '_last_lr': [0.0001]}
# Epoch 14/50, Train Loss: 0.003934313368914475
# Validation Loss: 0.004321461402079356, F1: 0.3706658235131145, P: 0.31386828500786695, R: 0.5516151179924704
# Validation loss decreased (0.004345 --> 0.004321).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004321461402079356, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 14, '_last_lr': [0.0001]}
# Epoch 15/50, Train Loss: 0.003886948617504463
# Validation Loss: 0.004320453607942909, F1: 0.3724005671486106, P: 0.31594515621487973, R: 0.5538574843024542
# Validation loss decreased (0.004321 --> 0.004320).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004320453607942909, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 15, '_last_lr': [0.0001]}
# Epoch 16/50, Train Loss: 0.003844065890794819
# Validation Loss: 0.004315444868656673, F1: 0.3731194079090216, P: 0.316071027197123, R: 0.5552619723537393
# Validation loss decreased (0.004320 --> 0.004315).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004315444868656673, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 16, '_last_lr': [0.0001]}
# Epoch 17/50, Train Loss: 0.0038045905044874814
# Validation Loss: 0.00431626128764557, F1: 0.37340856492129476, P: 0.31638570465273097, R: 0.5561501158906182
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004315444868656673, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 17, '_last_lr': [0.0001]}
# Epoch 18/50, Train Loss: 0.003762287140262005
# Validation Loss: 0.00429944082529151, F1: 0.3753917557862587, P: 0.3183277140930546, R: 0.5588939291375249
# Validation loss decreased (0.004315 --> 0.004299).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00429944082529151, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 18, '_last_lr': [0.0001]}
# Epoch 19/50, Train Loss: 0.0037232499076497658
# Validation Loss: 0.004339909766401563, F1: 0.37054379427888245, P: 0.3136525061811643, R: 0.553076722277633
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00429944082529151, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 19, '_last_lr': [0.0001]}
# Epoch 20/50, Train Loss: 0.003683759798020841
# Validation Loss: 0.0043166976422071455, F1: 0.37170837362359066, P: 0.31501011463250167, R: 0.5534307797789538
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00429944082529151, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 20, '_last_lr': [9e-05]}
# Epoch 21/50, Train Loss: 0.003625355207151187
# Validation Loss: 0.004294049982646746, F1: 0.3751518314517811, P: 0.31800404585300074, R: 0.5585258987019357
# Validation loss decreased (0.004299 --> 0.004294).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004294049982646746, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 21, '_last_lr': [9e-05]}
# Epoch 22/50, Train Loss: 0.00358797187335651
# Validation Loss: 0.0042990928249699726, F1: 0.3763002891201696, P: 0.3186244099797707, R: 0.5612318744277509
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004294049982646746, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 22, '_last_lr': [9e-05]}
# Epoch 23/50, Train Loss: 0.0035551710609123843
# Validation Loss: 0.004294996171457959, F1: 0.37714244311257206, P: 0.3200359631377838, R: 0.5595252016995881
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004294049982646746, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 23, '_last_lr': [8.1e-05]}
# Epoch 24/50, Train Loss: 0.0035017453852997224
# Validation Loss: 0.004282016245581742, F1: 0.37746532149536444, P: 0.320323668240054, R: 0.5606228269774223
# Validation loss decreased (0.004294 --> 0.004282).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004282016245581742, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 24, '_last_lr': [8.1e-05]}
# Epoch 25/50, Train Loss: 0.0034688178638107706
# Validation Loss: 0.004275825173993196, F1: 0.3797578860782057, P: 0.3216543043380535, R: 0.5664538745622988
# Validation loss decreased (0.004282 --> 0.004276).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004275825173993196, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 25, '_last_lr': [8.1e-05]}
# Epoch 26/50, Train Loss: 0.0034372143250524173
# Validation Loss: 0.004274158021767757, F1: 0.3794463503013815, P: 0.3221937514048101, R: 0.564251212756403
# Validation loss decreased (0.004276 --> 0.004274).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004274158021767757, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 26, '_last_lr': [8.1e-05]}
# Epoch 27/50, Train Loss: 0.0034055618375728723
# Validation Loss: 0.0043059714205030885, F1: 0.3775630693685025, P: 0.32020678804225666, R: 0.5626481727588035
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004274158021767757, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 27, '_last_lr': [8.1e-05]}
# Epoch 28/50, Train Loss: 0.0033775202451093314
# Validation Loss: 0.004355643120860415, F1: 0.37511324508946103, P: 0.31800404585300074, R: 0.5594554394446015
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004274158021767757, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 28, '_last_lr': [7.290000000000001e-05]}
# Epoch 29/50, Train Loss: 0.0033310966076749537
# Validation Loss: 0.004313875195969428, F1: 0.3779487217611862, P: 0.32095302315126994, R: 0.5613889179815005
# EarlyStopping counter: 3 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004274158021767757, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 29, '_last_lr': [7.290000000000001e-05]}
# Epoch 30/50, Train Loss: 0.0033029525469034
# Validation Loss: 0.0043095559480467015, F1: 0.37696608192299536, P: 0.32030568667116205, R: 0.5594153563122873
# EarlyStopping counter: 4 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004274158021767757, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 30, '_last_lr': [6.561000000000002e-05]}
# Epoch 31/50, Train Loss: 0.003261907042739497
# Validation Loss: 0.004319401991753174, F1: 0.3800516532177062, P: 0.32172623061362104, R: 0.5678963138251147
# EarlyStopping counter: 5 out of 5
# Early stopping triggered!
# Test Loss: 0.005911884735011168, Test Precision: 0.26747243426632744, Test Recall: 0.4501406716792814, Test F1: 0.3037698767116912, Test AuC: 0.9195463863591871
# Finished training for seed 66.
# Finishing last run (ID:e1r6mgs3) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>▁</td></tr><tr><td>test/loss</td><td>▁</td></tr><tr><td>test/sF1@25</td><td>▁</td></tr><tr><td>test/sPrecision@25</td><td>▁</td></tr><tr><td>test/sRecall@25</td><td>▁</td></tr><tr><td>train/loss</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/lr</td><td>████████████████████▆▆▆▄▄▄▄▄▂▂▁</td></tr><tr><td>val/loss</td><td>█▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/sF1@25</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇████▇▇███████████</td></tr><tr><td>val/sPrecision@25</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇████▇▇███████████</td></tr><tr><td>val/sRecall@25</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇▇▇██▇▇███████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>0.91955</td></tr><tr><td>test/loss</td><td>0.00591</td></tr><tr><td>test/sF1@25</td><td>0.30377</td></tr><tr><td>test/sPrecision@25</td><td>0.26747</td></tr><tr><td>test/sRecall@25</td><td>0.45014</td></tr><tr><td>train/loss</td><td>0.00326</td></tr><tr><td>train/lr</td><td>7e-05</td></tr><tr><td>val/loss</td><td>0.00432</td></tr><tr><td>val/sF1@25</td><td>0.38005</td></tr><tr><td>val/sPrecision@25</td><td>0.32173</td></tr><tr><td>val/sRecall@25</td><td>0.5679</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ResNet6-LandsatCubes-seed_66_opt_AdamW_lr_0.0001_batch_32_weight1</strong> at: <a href='https://wandb.ai/picekl/GeoPlant/runs/e1r6mgs3' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/e1r6mgs3</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241029_211033-e1r6mgs3/logs</code>
# Successfully finished last run (ID:e1r6mgs3). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666822053375654, max=1.0)…
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/Projects/NIPS-GLC24/baselines-v2/landsat/wandb/run-20241029_213253-2yca012y</code>
# Syncing run <strong><a href='https://wandb.ai/picekl/GeoPlant/runs/2yca012y' target="_blank">ResNet6-LandsatCubes-seed_123_opt_AdamW_lr_0.0001_batch_32_weight1</a></strong> to <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">https://wandb.ai/picekl/GeoPlant</a>
#  View run at <a href='https://wandb.ai/picekl/GeoPlant/runs/2yca012y' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/2yca012y</a>
# Epoch 1/50, Train Loss: 0.013112512925099708
# Validation Loss: 0.005592841837954309, F1: 0.2702208566505937, P: 0.22940885592267926, R: 0.39314022154432504
# Validation loss decreased (inf --> 0.005593).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.005592841837954309, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 1, '_last_lr': [0.0001]}
# Epoch 2/50, Train Loss: 0.005193130459081604
# Validation Loss: 0.004973323001260204, F1: 0.3183845152041364, P: 0.269291975724882, R: 0.4710953160902911
# Validation loss decreased (0.005593 --> 0.004973).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004973323001260204, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 2, '_last_lr': [0.0001]}
# Epoch 3/50, Train Loss: 0.00481715504493195
# Validation Loss: 0.004735536113314863, F1: 0.3344034388386123, P: 0.2822387053270399, R: 0.4978869763697824
# Validation loss decreased (0.004973 --> 0.004736).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004735536113314863, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 3, '_last_lr': [0.0001]}
# Epoch 4/50, Train Loss: 0.004617815101142045
# Validation Loss: 0.0047028095428166645, F1: 0.33673870364386504, P: 0.2841627331984716, R: 0.5027557154607224
# Validation loss decreased (0.004736 --> 0.004703).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0047028095428166645, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 4, '_last_lr': [0.0001]}
# Epoch 5/50, Train Loss: 0.004487381394008523
# Validation Loss: 0.004536928178276866, F1: 0.3504873855977178, P: 0.2965700157338728, R: 0.5214734708978219
# Validation loss decreased (0.004703 --> 0.004537).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004536928178276866, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 5, '_last_lr': [0.0001]}
# Epoch 6/50, Train Loss: 0.004389665902868607
# Validation Loss: 0.004523971799894103, F1: 0.3498014896866793, P: 0.29630928298494047, R: 0.5201325437624077
# Validation loss decreased (0.004537 --> 0.004524).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004523971799894103, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 6, '_last_lr': [0.0001]}
# Epoch 7/50, Train Loss: 0.0043111995061193955
# Validation Loss: 0.004467719457378345, F1: 0.35671192502340493, P: 0.30217127444369524, R: 0.5298785011333971
# Validation loss decreased (0.004524 --> 0.004468).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004467719457378345, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 7, '_last_lr': [0.0001]}
# Epoch 8/50, Train Loss: 0.004240983424540454
# Validation Loss: 0.004414955857542476, F1: 0.36042722623236145, P: 0.3049763991908294, R: 0.5364184958325957
# Validation loss decreased (0.004468 --> 0.004415).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004414955857542476, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 8, '_last_lr': [0.0001]}
# Epoch 9/50, Train Loss: 0.0041795082832351725
# Validation Loss: 0.004380575530896229, F1: 0.36445291525281936, P: 0.3092380310182064, R: 0.5403455392549791
# Validation loss decreased (0.004415 --> 0.004381).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004380575530896229, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 9, '_last_lr': [0.0001]}
# Epoch 10/50, Train Loss: 0.004124094793794396
# Validation Loss: 0.004376986380001264, F1: 0.36510903600892297, P: 0.3092020678804226, R: 0.5435135645856094
# Validation loss decreased (0.004381 --> 0.004377).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004376986380001264, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 10, '_last_lr': [0.0001]}
# Epoch 11/50, Train Loss: 0.004070154920341637
# Validation Loss: 0.004393944014529032, F1: 0.36259709365355924, P: 0.30787143178242304, R: 0.5380900384409895
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004376986380001264, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 11, '_last_lr': [0.0001]}
# Epoch 12/50, Train Loss: 0.00402169213203726
# Validation Loss: 0.004327655723318458, F1: 0.36849571649316254, P: 0.3123668240053945, R: 0.5479576207770044
# Validation loss decreased (0.004377 --> 0.004328).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004327655723318458, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 12, '_last_lr': [0.0001]}
# Epoch 13/50, Train Loss: 0.0039747227267076645
# Validation Loss: 0.004355329009039062, F1: 0.36849595862350343, P: 0.3111350865363003, R: 0.5520149170649078
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004327655723318458, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 13, '_last_lr': [0.0001]}
# Epoch 14/50, Train Loss: 0.0039289405108179215
# Validation Loss: 0.004346984581622694, F1: 0.36985166220766835, P: 0.31293324342548895, R: 0.5521957478795317
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004327655723318458, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 14, '_last_lr': [9e-05]}
# Epoch 15/50, Train Loss: 0.0038679861623996882
# Validation Loss: 0.004306937707588077, F1: 0.3713394163177682, P: 0.31465947403910993, R: 0.5530817024902912
# Validation loss decreased (0.004328 --> 0.004307).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004306937707588077, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 15, '_last_lr': [9e-05]}
# Epoch 16/50, Train Loss: 0.0038262349025527526
# Validation Loss: 0.004285611804308636, F1: 0.3758580396909113, P: 0.31806698134412226, R: 0.5602950178733457
# Validation loss decreased (0.004307 --> 0.004286).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004285611804308636, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 16, '_last_lr': [9e-05]}
# Epoch 17/50, Train Loss: 0.003787085764148159
# Validation Loss: 0.004282255595483418, F1: 0.3742014924128819, P: 0.317015059563947, R: 0.5570619957220591
# Validation loss decreased (0.004286 --> 0.004282).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004282255595483418, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 17, '_last_lr': [9e-05]}
# Epoch 18/50, Train Loss: 0.0037469228557406174
# Validation Loss: 0.004291479618820761, F1: 0.37501176440199124, P: 0.31767138682850077, R: 0.5593122914086139
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004282255595483418, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 18, '_last_lr': [9e-05]}
# Epoch 19/50, Train Loss: 0.0037088438536813885
# Validation Loss: 0.004279243166092783, F1: 0.377173975345211, P: 0.31964036862216233, R: 0.5613462326543194
# Validation loss decreased (0.004282 --> 0.004279).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004279243166092783, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 19, '_last_lr': [9e-05]}
# ...
# Epoch 20/50, Train Loss: 0.003651051111427685
# Validation Loss: 0.0042808208481541704, F1: 0.37557091927357994, P: 0.31842661272196, R: 0.558983648391405
# EarlyStopping counter: 5 out of 5
# Early stopping triggered!
# Test Loss: 0.005770370658373812, Test Precision: 0.26645462256149277, Test Recall: 0.4461952806731344, Test F1: 0.3026101886521392, Test AuC: 0.9225385958434901
# Finished training for seed 777.
# Finishing last run (ID:wj6iq3jx) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>▁</td></tr><tr><td>test/loss</td><td>▁</td></tr><tr><td>test/sF1@25</td><td>▁</td></tr><tr><td>test/sPrecision@25</td><td>▁</td></tr><tr><td>test/sRecall@25</td><td>▁</td></tr><tr><td>train/loss</td><td>█▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/lr</td><td>█████████████████▄▄▁</td></tr><tr><td>val/loss</td><td>█▆▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/sF1@25</td><td>▁▃▅▆▆▆▆▇▇▇▇█████████</td></tr><tr><td>val/sPrecision@25</td><td>▁▃▅▆▆▇▆▇▇▇▇█████████</td></tr><tr><td>val/sRecall@25</td><td>▁▃▅▆▆▆▆▇▇▇▇█▇███████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>0.92254</td></tr><tr><td>test/loss</td><td>0.00577</td></tr><tr><td>test/sF1@25</td><td>0.30261</td></tr><tr><td>test/sPrecision@25</td><td>0.26645</td></tr><tr><td>test/sRecall@25</td><td>0.4462</td></tr><tr><td>train/loss</td><td>0.00365</td></tr><tr><td>train/lr</td><td>8e-05</td></tr><tr><td>val/loss</td><td>0.00428</td></tr><tr><td>val/sF1@25</td><td>0.37557</td></tr><tr><td>val/sPrecision@25</td><td>0.31843</td></tr><tr><td>val/sRecall@25</td><td>0.55898</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ResNet6-LandsatCubes-seed_777_opt_AdamW_lr_0.0001_batch_32_weight1</strong> at: <a href='https://wandb.ai/picekl/GeoPlant/runs/wj6iq3jx' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/wj6iq3jx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241029_215122-wj6iq3jx/logs</code>
# Successfully finished last run (ID:wj6iq3jx). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666877553216182, max=1.0)…
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/Projects/NIPS-GLC24/baselines-v2/landsat/wandb/run-20241029_220718-egcv96bx</code>
# Syncing run <strong><a href='https://wandb.ai/picekl/GeoPlant/runs/egcv96bx' target="_blank">ResNet6-LandsatCubes-seed_999_opt_AdamW_lr_0.0001_batch_32_weight1</a></strong> to <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/picekl/GeoPlant' target="_blank">https://wandb.ai/picekl/GeoPlant</a>
#  View run at <a href='https://wandb.ai/picekl/GeoPlant/runs/egcv96bx' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/egcv96bx</a>
# Epoch 1/50, Train Loss: 0.013070765401030145
# Validation Loss: 0.00562251890078187, F1: 0.2798375850257019, P: 0.23727579231287932, R: 0.4072875741800322
# Validation loss decreased (inf --> 0.005623).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00562251890078187, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 1, '_last_lr': [0.0001]}
# Epoch 2/50, Train Loss: 0.005194018263564382
# Validation Loss: 0.005002780499801572, F1: 0.31769999421852213, P: 0.2682400539447067, R: 0.4720391132042512
# Validation loss decreased (0.005623 --> 0.005003).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.005002780499801572, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 2, '_last_lr': [0.0001]}
# Epoch 3/50, Train Loss: 0.004815683984176526
# Validation Loss: 0.004748626667008336, F1: 0.33502934502594944, P: 0.28375814789840414, R: 0.49628198229001247
# Validation loss decreased (0.005003 --> 0.004749).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004748626667008336, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 3, '_last_lr': [0.0001]}
# Epoch 4/50, Train Loss: 0.004618536180024861
# Validation Loss: 0.004598191079484033, F1: 0.34585261614659246, P: 0.2928298494043605, R: 0.5130267800262892
# Validation loss decreased (0.004749 --> 0.004598).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004598191079484033, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 4, '_last_lr': [0.0001]}
# Epoch 5/50, Train Loss: 0.004486682682289664
# Validation Loss: 0.0045951950031199625, F1: 0.3473857282883744, P: 0.29300966509327936, R: 0.5200761642223255
# Validation loss decreased (0.004598 --> 0.004595).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.0045951950031199625, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 5, '_last_lr': [0.0001]}
# Epoch 6/50, Train Loss: 0.004386264822367553
# Validation Loss: 0.004493059187994471, F1: 0.35513934839377065, P: 0.3003731175545067, R: 0.5279685045535317
# Validation loss decreased (0.004595 --> 0.004493).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004493059187994471, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 6, '_last_lr': [0.0001]}
# Epoch 7/50, Train Loss: 0.0043054952278781195
# Validation Loss: 0.004439024873343962, F1: 0.3600582152585721, P: 0.3049134636997078, R: 0.5350175684296478
# Validation loss decreased (0.004493 --> 0.004439).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004439024873343962, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 7, '_last_lr': [0.0001]}
# Epoch 8/50, Train Loss: 0.004236593656999783
# Validation Loss: 0.00443062024257545, F1: 0.3591246933210789, P: 0.3038615419195325, R: 0.5354404447359865
# Validation loss decreased (0.004439 --> 0.004431).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.00443062024257545, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 8, '_last_lr': [0.0001]}
# Epoch 9/50, Train Loss: 0.004177030272422997
# Validation Loss: 0.004387232646279569, F1: 0.3647346055637508, P: 0.30908518768262533, R: 0.5420946676885587
# Validation loss decreased (0.004431 --> 0.004387).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004387232646279569, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 9, '_last_lr': [0.0001]}
# Epoch 10/50, Train Loss: 0.004118254556909999
# Validation Loss: 0.004342543548305652, F1: 0.36934932975157886, P: 0.3125646212632052, R: 0.5506927440617317
# Validation loss decreased (0.004387 --> 0.004343).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004342543548305652, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 10, '_last_lr': [0.0001]}
# Epoch 11/50, Train Loss: 0.004067897457607586
# Validation Loss: 0.004389152734074741, F1: 0.3675220259027812, P: 0.3116115981119353, R: 0.5463404998568356
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004342543548305652, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 11, '_last_lr': [0.0001]}
# Epoch 12/50, Train Loss: 0.004017839013309099
# Validation Loss: 0.004319889597328646, F1: 0.37065760752272126, P: 0.3138772757923129, R: 0.551958343734705
# Validation loss decreased (0.004343 --> 0.004320).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004319889597328646, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 12, '_last_lr': [0.0001]}
# Epoch 13/50, Train Loss: 0.003970168037519824
# Validation Loss: 0.0043615434485088506, F1: 0.3660306523729223, P: 0.3094268374915712, R: 0.5468585716403922
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004319889597328646, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 13, '_last_lr': [0.0001]}
# Epoch 14/50, Train Loss: 0.003921405058604419
# Validation Loss: 0.004325201127877725, F1: 0.3703620530333127, P: 0.3139042481456507, R: 0.5514859082639163
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004319889597328646, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 14, '_last_lr': [9e-05]}
# Epoch 15/50, Train Loss: 0.003862818531384642
# Validation Loss: 0.004271050853588219, F1: 0.37639881194928654, P: 0.31889413351314905, R: 0.5611607599712617
# Validation loss decreased (0.004320 --> 0.004271).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004271050853588219, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 15, '_last_lr': [9e-05]}
# Epoch 16/50, Train Loss: 0.003819358889556389
# Validation Loss: 0.004312140517868102, F1: 0.3715065859895988, P: 0.3145695661946505, R: 0.5547429421775878
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004271050853588219, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 16, '_last_lr': [9e-05]}
# Epoch 17/50, Train Loss: 0.0037810686871023068
# Validation Loss: 0.004300547399491604, F1: 0.3735996993991978, P: 0.3173027646662171, R: 0.5538526290217096
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004271050853588219, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 17, '_last_lr': [8.1e-05]}
# Epoch 18/50, Train Loss: 0.0037241312077679277
# Validation Loss: 0.004267369022792471, F1: 0.375450181874661, P: 0.318588446841987, R: 0.5580427796575622
# Validation loss decreased (0.004271 --> 0.004267).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004267369022792471, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 18, '_last_lr': [8.1e-05]}
# Epoch 19/50, Train Loss: 0.003687186197929062
# Validation Loss: 0.004249963997530618, F1: 0.37887141080764597, P: 0.32164531355360754, R: 0.5626439304157081
# Validation loss decreased (0.004267 --> 0.004250).  Saving model ...
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004249963997530618, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 19, '_last_lr': [8.1e-05]}
# Epoch 20/50, Train Loss: 0.0036514458694388804
# Validation Loss: 0.0042818165816632765, F1: 0.3763326436507899, P: 0.3189930321420544, R: 0.5606321700121412
# EarlyStopping counter: 1 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004249963997530618, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 20, '_last_lr': [8.1e-05]}
# Epoch 21/50, Train Loss: 0.0036174671262302447
# Validation Loss: 0.004292321424665195, F1: 0.37494545866630513, P: 0.3180579905596763, R: 0.5580572992659761
# EarlyStopping counter: 2 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004249963997530618, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 21, '_last_lr': [7.290000000000001e-05]}
# Epoch 22/50, Train Loss: 0.003567457567289878
# Validation Loss: 0.004252778617332556, F1: 0.3803110958441893, P: 0.3224544841537424, R: 0.5662090198473647
# EarlyStopping counter: 3 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004249963997530618, 'num_bad_epochs': 1, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 22, '_last_lr': [7.290000000000001e-05]}
# Epoch 23/50, Train Loss: 0.003537390363296208
# Validation Loss: 0.004292112750200821, F1: 0.3760459996751447, P: 0.319055967633176, R: 0.5592000166089411
# EarlyStopping counter: 4 out of 5
# Scheduler: {'factor': 0.9, 'min_lrs': [0], 'patience': 1, 'verbose': False, 'cooldown': 0, 'cooldown_counter': 0, 'mode': 'min', 'threshold': 0.0001, 'threshold_mode': 'rel', 'best': 0.004249963997530618, 'num_bad_epochs': 0, 'mode_worse': inf, 'eps': 1e-08, 'last_epoch': 23, '_last_lr': [6.561000000000002e-05]}
# Epoch 24/50, Train Loss: 0.0034911583298831376
# Validation Loss: 0.0042585821905439455, F1: 0.379746616725052, P: 0.3216722859069454, R: 0.5665511830720167
# EarlyStopping counter: 5 out of 5
# Early stopping triggered!
# Test Loss: 0.005793040286359453, Test Precision: 0.26893129770992363, Test Recall: 0.45186332142855795, Test F1: 0.3054157199709439, Test AuC: 0.922886533831037
# Finished training for seed 999.

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>▁</td></tr><tr><td>test/loss</td><td>▁</td></tr><tr><td>test/sF1@25</td><td>▁</td></tr><tr><td>test/sPrecision@25</td><td>▁</td></tr><tr><td>test/sRecall@25</td><td>▁</td></tr><tr><td>train/loss</td><td>█▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/lr</td><td>██████████████▆▆▆▄▄▄▄▂▂▁</td></tr><tr><td>val/loss</td><td>█▅▄▃▃▂▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/sF1@25</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇█▇████████</td></tr><tr><td>val/sPrecision@25</td><td>▁▄▅▆▆▆▇▆▇▇▇▇▇▇█▇████████</td></tr><tr><td>val/sRecall@25</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇█▇▇███████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/AUC</td><td>0.92289</td></tr><tr><td>test/loss</td><td>0.00579</td></tr><tr><td>test/sF1@25</td><td>0.30542</td></tr><tr><td>test/sPrecision@25</td><td>0.26893</td></tr><tr><td>test/sRecall@25</td><td>0.45186</td></tr><tr><td>train/loss</td><td>0.00349</td></tr><tr><td>train/lr</td><td>7e-05</td></tr><tr><td>val/loss</td><td>0.00426</td></tr><tr><td>val/sF1@25</td><td>0.37975</td></tr><tr><td>val/sPrecision@25</td><td>0.32167</td></tr><tr><td>val/sRecall@25</td><td>0.56655</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ResNet6-LandsatCubes-seed_999_opt_AdamW_lr_0.0001_batch_32_weight1</strong> at: <a href='https://wandb.ai/picekl/GeoPlant/runs/egcv96bx' target="_blank">https://wandb.ai/picekl/GeoPlant/runs/egcv96bx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241029_220718-egcv96bx/logs</code>
